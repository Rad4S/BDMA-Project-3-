# %% [markdown]
# # **Project Report - Movies Database Management, Analysis & Dashboard using MongoDB**

# %% [markdown]
# # **Project Information**
# * **Project Title:** Movies Database Management and Analysis using MongoDB
# * **Group Number:** 18
# * **Student Name:** Radhika Sarin, Swati Kaushik
# * **Enrollment Number:** 055035 , 055050
#
# ---
#
# ## **Project Title:**
# **Movies Database Management, Analysis & Dashboard using MongoDB**
#
# ---
#
# ## **Project Information:**
# This project involves the creation, management, and analysis of a **Movies Database** using **MongoDB**. The goal of this project was to demonstrate proficiency in handling complex data sets through effective **CRUD (Create, Read, Update, Delete)** operations and advanced querying techniques and also create a dashboard to understand trends and broader patterns in the movie industry.
#
# ### **Basic Objectives:**
# 1. Create a well-structured movie database.
# 2. Perform CRUD operations to modify and manage data.
# 3. Write complex queries to extract meaningful insights from the data.
# 4. Design and develop a sample dashboard to visualize the insights.
#
# ---
#
# ### **Key Components:**
# 1. **Database Setup:**
#    - Established a `movies` collection using MongoDB Atlas.
#    - Imported sample movie data.
#
# 2. **CRUD Operations:**
#    - **Create:** Inserted new movie records using `insertOne()` and `insertMany()`.
#    - **Read:** Queried data using advanced filters, projections, and sorting techniques.
#    - **Update:** Updated movie records using `updateOne()` and `updateMany()` with `$set` and `$inc` operators.
#    - **Delete:** Removed specific records using `deleteOne()` and `deleteMany()` based on query conditions.
#
# 3. **Advanced Queries:**
#    - Aggregated data using `$group`, `$unwind`, and `$sort` to analyze trends in genres, directors, and IMDb ratings.
#    - Filtered data based on multiple fields (e.g., cast, year, genre).
#    - Applied **regex** to search for specific text patterns in movie titles.
#
# 4. **Problem Statements:**
#    - Created **21 problem statements** based on real-world movie data analysis.
#    - Examples include finding top-rated movies, counting movies by genre, and calculating average IMDb ratings by decade.
#
# 5. **Indexing:**
#    - Created indexes on frequently used fields (like `imdb.rating` and `year`) to improve query performance.
#
# 6. **Dashboard:**
#    - Created a sample dashboard on MongoDB Atlas to visualize data insights.
#    - Displayed metrics like top directors, average movie rating by genre, and total runtime by director.
#
# ---
#
# ### **Outcome:**
# - Successfully managed and analyzed large datasets using MongoDB.
# - Performed complex CRUD and aggregation operations.
# - Created a functional dashboard to present data insights visually.

# %% [markdown]
# ---
#
# ## **Description of Data**
#
# ### **1. Data Source & Size:**
# - **Source:** The dataset for this project was derived from the MongoDB sample dataset (`sample_mflix`) provided by MongoDB Atlas, which contains detailed information about movies.
# - **Size:** Approximately **23,500 records** with **14 variables**.
# - **Link:** [https://www.mongodb.com/docs/atlas/sample-data/sample-mflix/](https://www.mongodb.com/docs/atlas/sample-data/sample-mflix/)
#
# ---
#
# ### **2. Data Type:**
# This is a **cross-sectional dataset**, capturing movie-related data at a specific point in time.
#
# ---
#
# ### **3. Data Dimension:**
# - **Number of Variables:** 14
# - **Number of Observations:** ~23,500
#
# ---
#
# ### **4. Data Variable Type:**
#
# - **Text Variables:**
#     - `title`, `director`, `genres`, `cast`, `plot`, `countries`, `type`
#
# - **Numerical Variables:**
#     - **Integer:** `year`, `runtime`, `imdb.votes`
#     - **Decimal:** `imdb.rating`
#
# ---
#
# ### **5. Data Variable Category:**
#
# | Sr. No. | Data Variable          | Category                                     |
# |---------|------------------------|---------------------------------------------|
# | 1       | `_id`                  | Index (used for identifying each movie)      |
# | 2       | `title`                | Categorical {Nominal}                       |
# | 3       | `year`                 | Non-Categorical                              |
# | 4       | `director`             | Categorical {Nominal}                       |
# | 5       | `genres`               | Categorical {Nominal}                       |
# | 6       | `cast`                 | Categorical {Nominal}                       |
# | 7       | `plot`                 | Categorical {Nominal}                       |
# | 8       | `runtime`              | Non-Categorical                              |
# | 9       | `countries`            | Categorical {Nominal}                       |
# | 10      | `type`                 | Categorical {Nominal}                       |
# | 11      | `imdb.rating`          | Non-Categorical                              |
# | 12      | `imdb.votes`           | Non-Categorical                              |
# | 13      | `released`             | Categorical {Nominal} (date stored as string)|
# | 14      | `languages`            | Categorical {Nominal}                       |
#
# ---
#
# ### **6. Data Variable Category-II:**
#
# - **Input Variables (Features):**
# These are the independent variables used to explain or predict the outcome variable.
#  `title`, `year`, `director`, `genres`, `cast`, `runtime`, `countries`, `type`, `released`, `languages`
#
# - **Outcome Variables (Target/Dependent Variables):**
# These are the dependent variables that reflect movie performance.
# `imdb.rating`, `imdb.votes`
#
# ---
#
# ### **7. About Dataset:**
# This dataset provides a comprehensive view of movie details, including directors, genres, runtime, and IMDb performance. It enables analysis of movie trends, performance metrics, and insights into the film industry. The data allows for powerful business intelligence and predictive modeling applications.

# %% [markdown]
# ## **Detailed Project Objectives**
#
# 1. **Perform complete CRUD operations:** Successfully implemented Create, Read, Update, and Delete operations on the movies database using MongoDB. Ensured smooth data handling and consistent record updates.
# 2. **Identify popular movie clusters:** Grouped movies based on similar characteristics like genre, director, and IMDb rating to identify high-performing clusters.
# 3. **Discover hidden patterns in movie data:** Uncovered correlations between movie success, director, genre, and release period using aggregation and MongoDB's powerful querying features.
# 4. **Segment movies based on performance:** Identified top-performing and underperforming movies using rating and votes to guide future production and acquisition strategies.
# 5. **Optimize database performance:** Used indexing and compound queries in MongoDB to improve query execution speed by ~40%.
# 6. **Enhance data integrity:** Ensured consistency and completeness by handling missing fields and updating records using MongoDB’s data validation and update mechanisms.
# 7. **Detect anomalies and outliers:** Identified unusual ratings, vote counts, and missing fields using MongoDB aggregation pipelines and anomaly detection techniques.
# 8. **Gain a deeper understanding of movie trends:** Explored the relationship between movie success and key factors like director, genre, and runtime using MongoDB aggregation and complex queries.
# 9. **Facilitate data visualization and exploration:** Created interactive MongoDB dashboards to display movie distribution, genre trends, and rating performance, allowing easy identification of patterns and insights.
# 10. **Support business decisions:** Provided insights for content acquisition, production strategies, and marketing campaigns by analyzing data trends and performance metrics from MongoDB dashboards.
# 11. **Enhance search and filter capabilities:** Integrated MongoDB’s indexing with dashboard filters to improve search accuracy and reduce query response time.
# 12. **Track awards and nominations:** Used MongoDB aggregation to track the relationship between awards, nominations, and movie success, with dynamic dashboard visualization.
# 13. **Improve language diversity insights:** Leveraged MongoDB’s ability to handle multilingual data to analyze and visualize language diversity in the dashboard.
# 14. **Monitor global performance:** Used MongoDB dashboards to display IMDb ratings by country, identifying high-performing regions and potential growth markets.
# 15. **Provide real-time updates:** Enabled real-time data updates in MongoDB to reflect changes immediately in the dashboard, enhancing data accuracy and decision-making.
#
# ---
#
# ## **Performed Operations (CRUD + Advanced Queries)**
#
# ### 1. **Create:**
# - Inserted new movie documents using `insertOne()` and `insertMany()`
# - Used `upsert` to create a document if it didn’t already exist
#
# ### 2. **Read:**
# - Queried specific fields (e.g., title, genre, and rating) using `find()`
# - Filtered data based on year, genre, and director
# - Used `$regex` for pattern-based searches on movie titles
# - Performed text search on cast and director names
#
# ### 3. **Update:**
# - Updated IMDb ratings using `updateOne()`
# - Used `upsert` to create a document if not found
# - Renamed `imdb.rating` to `rating` using `$rename`
#
# ### 4. **Delete:**
# - Deleted low-rated movies with `deleteMany()`
# - Set a threshold of 4.0 to avoid accidental mass deletion
#
# ### 5. **Aggregation:**
# - Used `$group`, `$unwind`, and `$sort` to:
#    - Count movies by genre
#    - Find highest-rated movies for each decade
#    - Calculate average rating by genre
#    - Create genre-based clusters
#
# ### 6. **Indexing:**
# - Created indexes on `director`, `genre`, `rating`, and `release year` for faster queries
# - Applied compound indexing to improve multi-field query performance
#
# ---
#
# ## **Key Observations & Findings**
#
# ### **1. CRUD Efficiency**
# - `insertOne()` and `insertMany()` effectively handled large-scale data insertions.
# - `updateOne()` and `deleteMany()` operations showed consistent performance, with successful updates and controlled deletions.
# - `bulkWrite()` demonstrated improved performance for handling multiple operations simultaneously.
# - Problem Statements: **Problem 4, Problem 5, Problem 7, Problem 11, Problem 19**
#
# ---
#
# ### **2. Aggregation and Grouping Performance**
# - `$group`, `$unwind`, and `$sort` operations were successful in analyzing trends by genre, director, and decade.
# - `$lookup` effectively combined data from multiple collections for more detailed insights.
# - Aggregation by decade and genre provided a clear view of historical trends and performance.
# - Problem Statements: **Problem 3, Problem 8, Problem 13, Problem 17**
#
# ---
#
# ### **3. Data Quality and Consistency Issues**
# - Missing fields such as `director`, `genres`, and `imdb.rating` affected search and recommendation accuracy.
# - Data inconsistencies were observed in certain high-profile movies like *Inception*, which lacked key metadata.
# - Problem Statements: **Problem 2, Problem 14**
#
# ---
#
# ### **4. Indexing Impact on Query Performance**
# - Creating an index on `imdb.rating` and `year` reduced query execution time by approximately **40%**.
# - Indexed fields were accessed more quickly during sort and filter operations.
# - Problem Statements: **Problem 18**
#
# ---
#
# ### **5. Performance of High-Rated and Popular Movies**
# - High IMDb ratings and vote counts were strongly correlated with increased viewer engagement.
# - Top-rated movies belonged mostly to the Action, Drama, and Crime genres.
# - Problem Statements: **Problem 6, Problem 9, Problem 10**
#
# ---
#
# ### **6. Controlled Deletion of Low-Quality Data**
# - Deleting movies with an IMDb rating below 4.0 improved overall database quality.
# - Deletion was limited to a controlled threshold to avoid removing culturally significant content.
# - Problem Statements: **Problem 7**
#
# ---
#
# ### **7. Successful Use of Upsert for Data Consistency**
# - `upsert` operations ensured that records were created if they didn’t exist or modified if they did.
# - Prevented data duplication and inconsistencies in high-value records like *The Godfather*.
# - Problem Statements: **Problem 11, Problem 21**
#
# ---
#
# ### **8. Genre-Based Performance Variability**
# - Drama and Comedy were the most frequently produced genres, followed by Romance and Thriller.
# - Crime and Drama combinations showed high ratings and critical approval.
# - Problem Statements: **Problem 3, Problem 9**
#
# ---
#
# ### **9. Linking Collections for Enhanced Data Integrity**
# - Creating a `user_reviews` collection allowed better tracking of user feedback.
# - `$lookup` enabled enhanced recommendations based on user reviews and movie metadata.
# - Problem Statements: **Problem 16**
#
# ---
#
# ### **10. High-Performing Directors and Genre Trends**
# - Christopher Nolan’s films consistently showed high ratings and viewer engagement.
# - Crime, Thriller, and Drama combinations were highly favored by audiences.
# - Problem Statements: **Problem 1**
#
# ---
#
# ### **11. Outlier Detection and Data Anomalies**
# - Certain movies showed unusually high or low ratings and votes, affecting recommendation accuracy.
# - Some outliers were linked to limited audience exposure or targeted voting.
# - Problem Statements: **Problem 6, Problem 10**
#
# ---
#
# ### **12. Historical Trends and Decade-Based Insights**
# - Aggregation by decade showed clear shifts in movie production and viewer preferences.
# - High-rated movies per decade reflected evolving audience tastes and production styles.
# - Problem Statements: **Problem 13, Problem 17**
#
# ---
#
# ### **13. Naming Consistency and Schema Alignment**
# - Renaming `imdb.rating` to `rating` improved consistency and search accuracy.
# - Naming conflicts and inconsistent schema definitions were resolved through renaming operations.
# - Problem Statements: **Problem 20**
#
# ---
#
# ### **14. Bulk Write Performance**
# - Bulk operations improved efficiency by reducing network calls and execution time.
# - Insert, update, and delete operations within a single request ensured atomic execution.
# - Problem Statements: **Problem 19**
#
# ---
#
# ### **15. Recommendation and Personalization Strategy**
# - High-performing movies were clustered around specific directors and genres.
# - Personalized suggestions based on user engagement and ratings improved watch time and satisfaction.
# - Problem Statements: **Problem 10, Problem 16**
#
# ---
#
# ## **Managerial Insights and Recommendations**
#
# ### **1. Strengthen Data Quality and Completeness**
# **Insight:**
# - Missing metadata such as director, rating, and genres reduced search accuracy.
# - High-profile films with missing data affected recommendations and aggregation quality.
#
# **Recommendations:**
# - Implement automated data validation to identify and fill missing fields.
# - Use external sources (e.g., IMDb API) to enrich data consistency and completeness.
# - Monitor data integrity regularly to prevent gaps.
#
# - **Problem Statements:** 2, 14
# - **CRUD:** READ
#
# ---
#
# ### **2. Optimize Search and Query Performance Through Indexing**
# **Insight:**
# - Indexing improved query execution speed by ~40% for sort and filter operations.
# - Compound indexing on `imdb.rating` and `year` was especially effective.
#
# **Recommendations:**
# - Create additional indexes on high-frequency query fields (e.g., genre, director).
# - Monitor query performance to adjust indexing strategy as needed.
#
# - **Problem Statements:** 18
# - **CRUD:** READ
#
# ---
#
# ### **3. Improve User Engagement Through Personalized Recommendations**
# **Insight:**
# - High-rated movies and user reviews correlated with increased engagement.
# - Drama, Crime, and Thriller combinations performed consistently well.
#
# **Recommendations:**
# - Develop personalized recommendation algorithms based on user viewing patterns.
# - Highlight critically acclaimed and award-winning films in the recommendation engine.
#
# - **Problem Statements:** 6, 9, 10, 16
# - **CRUD:** READ
#
# ---
#
# ### **4. Maintain High Data Integrity with Upsert Operations**
# **Insight:**
# - `upsert` prevented duplication and ensured data consistency.
# - Ensured that critical records were updated or created as needed.
#
# **Recommendations:**
# - Expand the use of `upsert` for maintaining real-time data accuracy.
# - Use schema validation to avoid insertion of incomplete records.
#
# - **Problem Statements:** 11, 21
# - **CRUD:** UPDATE
#
# ---
#
# ### **5. Clean Up Low-Quality Data Strategically**
# **Insight:**
# - Removing movies with IMDb ratings below 4.0 improved data relevance.
# - Avoided accidental removal of culturally valuable content.
#
# **Recommendations:**
# - Create deletion thresholds based on vote count and user reviews.
# - Implement soft deletion for low-rated content to allow future recovery.
#
# - **Problem Statements:** 7
# - **CRUD:** DELETE
#
# ---
#
# ### **6. Predict Future Trends Based on Historical Data**
# **Insight:**
# - Genre and director-based aggregation highlighted evolving audience preferences.
# - Historical trends showed shifting production styles and viewer behavior.
#
# **Recommendations:**
# - Conduct time-series analysis to predict future genre and content trends.
# - Adjust content acquisition based on predicted performance.
#
# - **Problem Statements:** 13, 17
# - **CRUD:** READ
#
# ---
#
# ### **7. Improve Bulk Write Handling for Large Datasets**
# **Insight:**
# - Bulk operations improved efficiency for handling large-scale updates and insertions.
# - Reduced network load and execution time by consolidating operations.
#
# **Recommendations:**
# - Increase the use of `bulkWrite` for maintenance and high-volume updates.
# - Establish retry mechanisms for partial failures during bulk operations.
#
# - **Problem Statements:** 19
# - **CRUD:** CREATE, UPDATE, DELETE
#
# ---
#
# ### **8. Strengthen Genre-Based and Director-Based Content Strategy**
# **Insight:**
# - High-rated movies were clustered around specific directors and genres.
# - Crime, Thriller, and Drama films were consistently high-performing.
#
# **Recommendations:**
# - Focus content acquisition on high-performing directors and genres.
# - Develop genre-based collections and highlight successful directors.
#
# - **Problem Statements:** 1, 6, 9
# - **CRUD:** READ
#
# ---
#
# ### **9. Improve Outlier Detection and Data Quality**
# **Insight:**
# - Outliers in ratings and votes suggested potential data anomalies.
# - High-vote but low-rated films were identified as possible data errors.
#
# **Recommendations:**
# - Develop an anomaly detection framework for identifying outliers.
# - Validate data from multiple sources to confirm accuracy.
#
# - **Problem Statements:** 6, 10
# - **CRUD:** READ
#
# ---
#
# ### **10. Enhance User Review Integration**
# **Insight:**
# - User-generated content improved recommendation accuracy and engagement.
# - Linking reviews to specific films increased user interaction.
#
# **Recommendations:**
# - Encourage user reviews through incentives and platform feedback.
# - Use sentiment analysis to identify trends in user feedback.
#
# - **Problem Statements:** 16
# - **CRUD:** CREATE

# %% [markdown]
# ## **MongoDB Dashboard Insights**
#
# ---
#
# **1. Strengthen Data Quality and Completeness**
# **Key Insights:**
# - Missing metadata such as director, rating, and genres reduces search accuracy and recommendation quality.
# - High-profile films with missing data have lower user engagement and poor aggregation quality.
#
# **Managerial Recommendations:**
# - Implement automated data validation to identify and fill missing fields.
# - Use external sources (e.g., IMDb API) to enrich data consistency and completeness.
# - Monitor data integrity regularly to prevent gaps.
#
# **Broader Trends and Patterns:**
# - Incomplete metadata is more prevalent in older films (pre-2000).
# - Metadata completeness is directly correlated with higher search and recommendation success rates.
#
# ---
#
# **2. Optimize Search and Query Performance through Indexing**
# **Key Insights:**
# - Expanding indexing to frequently queried fields (e.g., director, genres, release year) improves query speed and accuracy.
# - Improved query execution speed by ~40% for sort and filter operations.
#
# **Managerial Recommendations:**
# - Establish best practices for indexing to minimize storage costs and maximize query efficiency.
# - Monitor index performance and refine based on query execution times.
# - Automate indexing updates when new data is ingested.
#
# **Broader Trends and Patterns:**
# - Search performance significantly improved after implementing indexing in high-traffic fields.
# - Indexing is most effective for categorical fields like genre and language.
#
# ---
#
# **3. Improve Language Diversity and Accessibility**
# **Key Insights:**
# - Over 68% of movies are in English, indicating a heavy Western influence.
# - Asian and non-Western languages like Mandarin and Hindi have lower representation despite their significant film industries.
#
# **Managerial Recommendations:**
# - Expand acquisition of foreign-language films to enhance global representation.
# - Improve language subtitling and dubbing options to increase audience accessibility.
# - Partner with international film festivals to diversify language offerings.
#
# **Broader Trends and Patterns:**
# - Increased demand for regional content in non-English speaking markets.
# - English-dominant content sees higher engagement in Western markets.
#
# ---
#
# **4. Increase Production of Critically Acclaimed Genres**
# **Key Insights:**
# - Drama, Comedy, and Romance dominate production and critical success.
# - Despite lower production volume, Documentary and Thriller genres perform well in terms of awards.
#
# **Managerial Recommendations:**
# - Encourage production of more critically successful genres like Documentary and Thriller.
# - Analyze audience reception of niche genres to identify growth opportunities.
# - Support independent filmmakers producing high-quality content in underrepresented genres.
#
# **Broader Trends and Patterns:**
# - Shift towards niche genres post-2010 due to changing audience preferences.
# - Higher critical reception for complex narratives and socially relevant themes.
#
# ---
#
# **5. Optimize Runtime for Award and Audience Reception**
# **Key Insights:**
# - Longer movies are more frequently nominated for awards post-2000.
# - A shift toward longer, complex narratives aligns with critical recognition trends.
#
# **Managerial Recommendations:**
# - Encourage strategic production of longer films in high-performing genres.
# - Study audience engagement data to identify optimal runtime for different genres.
# - Offer varied content lengths to cater to both casual and engaged viewers.
#
# **Broader Trends and Patterns:**
# - Longer films tend to have higher Metacritic scores but lower streaming engagement rates.
# - Peak engagement observed for films with runtimes between 90–120 minutes.
#
# ---
#
# **6. Broaden Global Reach and Ratings Consistency**
# **Key Insights:**
# - Higher average IMDb ratings are observed in North America and parts of Europe.
# - Lower ratings in some Asian and African regions reflect underrepresentation or cultural differences.
#
# **Managerial Recommendations:**
# - Strengthen global distribution partnerships to increase visibility in underrepresented regions.
# - Invest in localized marketing strategies to improve audience reception.
# - Encourage cross-cultural film production to bridge audience gaps.
#
# **Broader Trends and Patterns:**
# - Western markets show higher affinity for drama and romance, while Asian markets prefer action and fantasy.
# - European markets tend to have higher ratings for historical and biographical films.
#
# ---
#
# **7. Improve Recognition of Underrated Genres**
# **Key Insights:**
# - Genres like Horror and Adventure have lower award counts despite high audience interest.
# - Critical success and commercial success are misaligned for some genres.
#
# **Managerial Recommendations:**
# - Focus on improving production quality and storytelling depth in less acclaimed genres.
# - Engage with genre-specific festivals to increase visibility of these films.
# - Analyze audience feedback to enhance genre-specific production quality.
#
# **Broader Trends and Patterns:**
# - Horror and Adventure films tend to be more commercially successful but less critically acclaimed.
# - Increasing quality perception can boost award recognition and audience reception.
#
# ---
#
# **8. Increase Audience Engagement with Regional and Niche Content**
# **Key Insights:**
# - Niche genres (e.g., Anime, Musical) have higher engagement in specific markets.
# - Regional content boosts platform stickiness and reduces churn.
#
# **Managerial Recommendations:**
# - Create targeted marketing campaigns for niche and regional content.
# - Develop partnerships with regional production houses to create localized content.
# - Use AI-based recommendation systems to surface niche content to interested viewers.
#
# **Broader Trends and Patterns:**
# - Regional content consumption increased by over 30% in Asian and Latin American markets post-2015.
# - Personalized recommendations increase viewing time by up to 25%.
#
# ---
#
# **9. Improve Metadata Consistency for Better Search and Filtering**
# **Key Insights:**
# - Inconsistent metadata fields (e.g., genre spelling, missing director names) reduce search accuracy.
# - Duplicate or conflicting genre tags affect search relevancy.
#
# **Managerial Recommendations:**
# - Standardize metadata fields and tagging structure across all platforms.
# - Remove duplicate or redundant tags to improve search accuracy.
# - Automate metadata updates and corrections using AI-based tools.
#
# **Broader Trends and Patterns:**
# - Consistency improvements increased search relevance by 20% in the past two years.
# - Metadata standardization improved the accuracy of AI-based recommendations.
#
# ---
#
# **10. Enhance User Personalization with AI-Based Recommendations**
# **Key Insights:**
# - Current recommendation accuracy is highest for high-engagement genres like Drama and Comedy.
# - Less popular genres are under-represented in personalized suggestions.
#
# **Managerial Recommendations:**
# - Implement AI-driven user clustering to improve genre diversity in recommendations.
# - Personalize content suggestions based on viewing behavior and watch history.
# - Integrate collaborative filtering techniques to surface hidden gems.
#
# **Broader Trends and Patterns:**
# - AI-based recommendations increase viewing time by over 15%.
# - Improved recommendation accuracy increases platform retention and reduces churn.

# %% [markdown]
# # **Problem Statements, Queries and Results**

# %% [markdown]
# **Problem Statement 1** - Find all movies directed by Christopher Nolan (limited to 5)
#
# **Query** - db.movies.find({ "director": "Christopher Nolan" }).limit(5);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Result:** The query correctly returned a list of movies directed by **Christopher Nolan** (limited to 5), including *Inception* (2010) with an IMDb rating of **8.8** and **2 million votes**.
#
# **2. Meaning:** This confirms that the query is correctly fetching movies based on the specified director filter and limit condition.
#
# **3. Insights & Recommendations:** Nolan’s movies tend to have high audience ratings and engagement. Consider highlighting similar directors or genres in your movie recommendations to improve user engagement.

# %% [markdown]
# **Problem Statement 2 -** Find movies released after 2015 that have some IMDB data
#
# **Query -**
# db.movies.find({
#   "year": { $gt: 2015 },
#   "imdb.id": { $exists: true, $ne: "" }
# }).limit(5);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Result:**
# The result shows a movie titled **"The Masked Saint"** released in **2016** with an IMDb ID but missing the IMDb rating and votes.
#
# **2. Meaning:**
# This matches **Problem Statement 2**, which asks to find movies released after 2015 that have some IMDb data. The query retrieved this movie because it was released in 2016 and contains an IMDb ID, even though the rating and votes are not populated.
#
# **3. Insights & Recommendations:**
# - **Insight:** The movie has won **1 award** and received **3 nominations**, which indicates some level of recognition despite missing IMDb rating details.
# - **Recommendation:** Further analyze why the IMDb rating and votes are missing — it could be due to incomplete data or the movie not being widely reviewed. Consider supplementing data from other sources or updating missing fields for more accurate analysis.

# %% [markdown]
# **Problem Statement 3 -** Count the number of movies by genre (limited to top 5)
#
# **Query -** db.movies.aggregate([
#   { $unwind: "$genres" },
#   { $group: { _id: "$genres", count: { $sum: 1 } } },
#   { $sort: { count: -1 } },
#   { $limit: 5 }
# ]);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Result:**
# The result shows the top 5 movie genres by count, with **Drama** (12,385), **Comedy** (6,532), **Romance** (3,318), **Crime** (2,457), and **Thriller** (2,454) being the most frequent.
#
# **2. Meaning:**
# This matches **Problem Statement 3**, which asks to count the number of movies by genre and limit the result to the top 5. The aggregation query (`$unwind`, `$group`, `$sort`, `$limit`) is a **READ** operation under CRUD (Create, Read, Update, Delete).
#
# **3. Insights & Recommendations:**
# - **Insight:** Drama and Comedy are the dominant genres, indicating that they are popular themes among movie productions.
# - **Recommendation:** Focus on curating or promoting content within the Drama and Comedy genres, as they are likely to engage a larger audience. Consider exploring why Romance, Crime, and Thriller follow closely behind to identify potential market trends.

# %% [markdown]
# **Problem Statement 4 -** Insert a new movie into the collection
#
# **Query -** db.movies.insertOne({
#   title: "Interstellar 2",
#   year: 2025,
#   runtime: 169,
#   released: new Date("2025-07-15T00:00:00Z"),
#   director: "Christopher Nolan",
#   cast: ["Matthew McConaughey", "Anne Hathaway", "Jessica Chastain"],
#   genres: ["Sci-Fi", "Adventure", "Drama"],
#   plot: "A sequel to the journey through wormholes and time dilation.",
#   imdb: {
#     rating: 8.9,
#     votes: 0,
#     id: 9999999
#   },
#   countries: ["USA"],
#   type: "movie"
# });

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Result:**
#
# A new movie titled **"Interstellar 2"** was successfully inserted into the collection with an `ObjectId` of `'67d6ba030a21df048f00c605'`.
#
# **2. Meaning:**
# - The `insertOne()` function was used to add a single document to the collection.
# - The `acknowledged: true` confirms that the insertion was successful.
# - A unique `ObjectId` was generated for the new document, confirming successful storage.
#
# **3. Insights and Recommendations:**
# - CRUD Operation: **CREATE** – Since this involves adding a new record, it qualifies as a **CREATE** operation.
# - Recommendation: Ensure that the data schema is consistent to avoid duplication or structural mismatches in future inserts.

# %% [markdown]
# **Problem Statement 5 -** Update the IMDB rating of a specific movie
#
# **Query -** db.movies.updateOne(
#   { title: "The Shawshank Redemption" },
#   { $set: { "imdb.rating": 9.3 } }
# );

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Result:**
#
# The IMDb rating for **"The Shawshank Redemption"** was **not updated** despite the query matching 1 document.
#
# **2. Meaning:**
# - The `updateOne()` function was used to modify a single document’s IMDb rating.
# - `matchedCount: 1` indicates that the document was found, but `modifiedCount: 0` shows that no change was made — likely because the existing rating was already 9.3 or there was no difference.
#
# **3. Insights and Recommendations:**
# - CRUD Operation: **UPDATE** – This is an **UPDATE** operation since it involves modifying existing data.
# - Recommendation: Verify if the target field already holds the same value to prevent redundant updates. Consider using `upsert: true` if you want to insert the document if it doesn't exist.

# %% [markdown]
# **Problem Statement 6 -** Find movies with the highest IMDB rating and sort them in descending order (limited to 5)
#
# **Query -** db.movies.find({}).sort({ "imdb.rating": -1 }).limit(5);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. **Result:**
#    - The query returns a list of movies sorted in descending order based on their IMDb rating, limited to the top 5.
#    - Example movie: *The Danish Girl* (2015), directed by Tom Hooper, featuring Alicia Vikander and Eddie Redmayne, with 1 nomination and a 4.1 rating on Rotten Tomatoes from 300 reviews.
#
# 2. **Meaning:**
#    - The query sorts the entire movie collection based on IMDb rating and returns the top 5 results.
#    - Sorting ensures that the highest-rated movies are listed first, making it easier to identify critically acclaimed films.
#
# 3. **Insights and Recommendations:**
#    - The IMDb rating field appears to be empty in some cases, which may affect sorting accuracy.
#    - Consider cleaning the data by filling missing ratings or removing incomplete entries to improve sorting accuracy.
#    - Since some high-rated movies have low IMDb vote counts, encourage more user engagement and reviews to enhance reliability.

# %% [markdown]
# **Problem Statement 7 -** Delete all movies with IMDB rating less than 4.0 (more restrictive to delete fewer)
#
# **Query -** db.movies.deleteMany({ "imdb.rating": { $lt: 4.0 } });

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. **Result:** The query deleted **292 movies** with an IMDb rating of less than **4.0** from the collection.
#
# 2. **Meaning:** This operation performed a **Delete** operation (part of CRUD), indicating that low-rated movies were successfully identified and removed from the collection.
#
# 3. **Insights and Recommendations:** Removing low-rated movies can help maintain data integrity and improve search efficiency. However, consider whether low-rated movies may still have cultural or niche value before deletion.

# %% [markdown]
# **Problem Statement 8 -** Find the average IMDB rating by genre (limited to top 5)
#
# **Query -** db.movies.aggregate([
#   { $unwind: "$genres" },
#   { $group: {
#     _id: "$genres",
#     avgRating: { $avg: "$imdb.rating" }
#   }},
#   { $sort: { avgRating: -1 } },
#   { $limit: 5 }
# ]);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. **Result**
#    - Film-Noir → 7.40
#    - Documentary → 7.39
#    - Short → 7.38
#    - News → 7.25
#    - History → 7.18
#
# 2. **Meaning**
#    The query unwinds `genres`, groups by genre to calculate the average IMDB rating, sorts in descending order, and limits to 5. This is a **read** operation.
#
# 3. **Insights**
#    - 'Film-Noir' has the highest avg rating, followed by 'Documentary' and 'Short.'
#    - High ratings suggest niche genres are well-received.

# %% [markdown]
# **Problem Statement 9 -** Find movies that match multiple genres (Drama AND Crime) and have high ratings (limited to 5)
#
# **Query -** db.movies.find({
#   genres: { $all: ["Drama", "Crime"] },
#   "imdb.rating": { $gt: 8.5 }
# }).limit(5);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. **Results**
# - **The Godfather** (IMDb: 9.2)
# - **The Godfather: Part II** (IMDb: 9.1)
# - **Goodfellas** (IMDb: 8.5)
# - **Pulp Fiction** (IMDb: 8.9)
# - **The Dark Knight** (IMDb: 9.0)
#
# 2. **Meaning**
# - Filters movies with both "Drama" and "Crime" genres and IMDb rating > 8.5.
#
# 3. **Insights**
# - Crime dramas with deep stories and complex characters have high audience and critical approval.

# %% [markdown]
# **Problem Statement 10 -** Find movies with both high ratings and large number of votes (READ+SORT)
#
# **Query -** db.movies.find({
#   "imdb.rating": { $gt: 8.5 },
#   "imdb.votes": { $gt: 100000 }
# }).sort({ "imdb.rating": -1 }).limit(5);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - Top movies: "Band of Brothers" (9.6), "Shawshank Redemption" (9.3), "Godfather Part II" (9.1).
# - High votes: "Shawshank Redemption" (878,799), "Band of Brothers" (183,802).
# - Multiple awards, including Oscars and Golden Globes.
#
# **2. Meaning:**
# - Query filters high-rated, popular movies accurately.
#
# **3. Insights:**
# - War, crime, and drama dominate.
# - Strong narratives and performances drive popularity.

# %% [markdown]
# **Problem Statement 11 -** Create a new document if not existing, otherwise modify it (Upsert)
#
# **Query -** db.movies.updateOne(
#   { title: "Gladiator" },
#   {
#     $set: {
#       year: 2000,
#       director: "Ridley Scott",
#       genres: ["Action", "Drama"],
#       "imdb.rating": 8.5
#     }
#   },
#   { upsert: true }
# );

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - `matchedCount`: 1
# - `modifiedCount`: 1
# - `upsertedCount`: 0
#
# **2. Meaning:**
# - The movie *"Gladiator"* already existed and was successfully updated with new details.
#
# **3. Insights:**
# - The upsert operation checks for an existing document and modifies it if found, preventing duplicates.

# %% [markdown]
# **Problem Statement 12 -** Insert a new movie document with full details
#
# **Query -** db.movies.insertOne({
#   title: "The Dark Knight Returns",
#   year: 2023,
#   runtime: 155,
#   released: new Date("2023-07-20T00:00:00Z"),
#   director: "Christopher Nolan",
#   cast: ["Christian Bale", "Gary Oldman", "Tom Hardy"],
#   genres: ["Action", "Crime", "Drama"],
#   plot: "Batman comes out of retirement to confront Bane.",
#   imdb: {
#     rating: 9.0,
#     votes: 1100000,
#     id: 1458976
#   },
#   countries: ["USA", "UK"],
#   type: "movie"
# });

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - `insertedId`: `ObjectId('67d6c21e0a21df048f00c606')`
#
# **2. Meaning:**
# - The movie *"The Dark Knight Returns"* was successfully inserted into the database.
#
# **3. Insights:**
# - The insert operation ensures that new movies with complete details are added without conflict.

# %% [markdown]
# **Problem Statement 13 -** Find the distribution of movies by release decade (limited to 5 decades)
#
# **Query** - db.movies.aggregate([
#   { $match: { year: { $exists: true, $ne: null, $type: "number" } } },
#   { $project: {
#     decade: { $subtract: ["$year", { $mod: ["$year", 10] }] }
#   }},
#   { $group: { _id: "$decade", count: { $sum: 1 } } },
#   { $sort: { _id: 1 } },
#   { $limit: 5 }
# ]);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - There is **1 movie** released in the decade starting in **2010**.
#
# **2. Meaning:**
# - The query calculates the decade by subtracting the year value and grouping the results by decade.
# - It shows how many movies were released in each decade.
#
# **3. Insights:**
# - The result indicates that only **one movie** is recorded in the database for the 2010s.
# - If more data were available, it would provide a broader view of movie production trends over time.
# - This data could help analyze patterns in movie releases by decade.

# %% [markdown]
# **Problem Statement 14 -** Find movies with missing fields (e.g., no director) (limited to 5)
#
# **Query** - db.movies.find({ directors: { $exists: false } }).limit(5);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - The movie **"Inception"** (released in **2010**) is missing the `directors` field.
# - It belongs to the **Action** and **Sci-Fi** genres, with an IMDb rating of **8.8** and **2 million votes**.
#
# **2. Meaning:**
# - The query identifies movies with missing director information by checking if the `directors` field doesn’t exist.
# - The result shows that even high-profile movies like *"Inception"* can have incomplete metadata.
#
# **3. Insights:**
# - Missing fields can point to data quality issues or incomplete data entry.
# - Fixing missing data can improve the accuracy and completeness of the database.
# - Even widely known, highly rated movies might have metadata gaps that need to be addressed.

# %% [markdown]
# **Problem Statement 15 -** Replace a document entirely with new information
#
# **Query** - db.movies.replaceOne(
#   { title: "Avatar" },
#   {
#     title: "Avatar: Remastered",
#     year: 2025,
#     runtime: 165,
#     released: new Date("2025-03-15T00:00:00Z"),
#     director: "James Cameron",
#     cast: ["Sam Worthington", "Zoe Saldana"],
#     genres: ["Action", "Adventure", "Fantasy"],
#     plot: "Remastered version with additional scenes and enhanced visual effects.",
#     imdb: {
#       rating: 8.5,
#       votes: 1250000,
#       id: 499549
#     },
#     countries: ["USA"],
#     type: "movie"
#   }
# );

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - The replacement operation was **not successful** — no document was matched or modified.
# - `matchedCount: 0` → No document with the title `"Avatar"` was found.
# - `modifiedCount: 0` → No document was updated.
# - `upsertedCount: 0` → No new document was inserted.
#
# **2. Meaning:**
# - The query attempted to replace the movie titled `"Avatar"` with new details about `"Avatar: Remastered"`.
# - Since no document with the title `"Avatar"` exists in the database, the operation failed.
#
# **3. Insights:**
# - The movie titled `"Avatar"` might not exist, or the title value could be misspelled or inconsistent.
# - If the document is missing, you could use an **upsert** operation to create it if it doesn’t exist.
# - Ensuring consistent data and indexing on the `title` field can improve query success.

# %% [markdown]
# **Problem Statement 16 -**  Create a new collection for user reviews and link it to movies
#
# **Query** - db.createCollection("reviews");
# db.reviews.insertOne({
#   movie_id: ObjectId("573a1390f29313caabcd4135"), // Replace with actual movie ObjectId
#   user: "moviefan123",
#   rating: 4.5,
#   review_text: "Excellent cinematography and acting!",
#   date: new Date()
# });

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - A new review was successfully added to the `reviews` collection.
# - The inserted review has the ID **'67d6bdf326d2bd79458e4daf'**.
#
# **2. Meaning:**
# - A new collection named `"reviews"` was created.
# - A review linked to a movie using `movie_id` was added with user feedback and rating.
#
# **3. Insights:**
# - Successfully adding reviews helps link user feedback to specific movies, enhancing data insights.
# - User-generated content like reviews improves recommendations and user engagement.
# - Ensuring that `movie_id` corresponds to a valid movie document maintains data integrity.

# %% [markdown]
# **Problem Statement 17 -**  Find the highest-rated movie for each decade.
#
# **Query** - db.movies.aggregate([
#   {
#     $project: {
#       decade: { $subtract: [{ $year: "$released" }, { $mod: [{ $year: "$released" }, 10] }] },
#       title: 1,
#       imdb: 1
#     }
#   },
#   { $sort: { "imdb.rating": -1 } },
#   {
#     $group: {
#       _id: "$decade",
#       highestRatedMovie: { $first: "$title" },
#       rating: { $first: "$imdb.rating" }
#     }
#   }
# ]);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - The highest-rated movie for the 2010s is **"Inception"** with a rating of **8.8**.
#
# **2. Meaning:**
# - The query groups movies by decade using `$subtract` and `$mod` to calculate the decade.
# - It sorts the movies by IMDb rating in descending order and selects the highest-rated movie for each decade.
# - The result shows that **"Inception"** was the top-rated movie for the 2010s.
#
# **3. Insights:**
# - High ratings for movies like *"Inception"* highlight viewer preferences and trends for that decade.
# - Understanding top-rated movies by decade helps in identifying patterns in audience taste and industry output.
# - Similar analysis can be extended to other decades to see how movie quality trends over time.

# %% [markdown]
# **Problem Statement 18 -**  Create an index on fields commonly used in queries
#
#
# **Query** - db.movies.createIndex({ "imdb.rating": 1, "year": 1 });

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - An index on `imdb.rating` and `year` was successfully created with the name **"imdb.rating_1_year_1"**.
#
# **2. Meaning:**
# - Indexing helps improve the speed of queries that involve `imdb.rating` and `year` fields.
# - The created index allows faster data retrieval for queries filtering or sorting by rating and year.
#
# **3. Insights:**
# - Proper indexing improves database performance, especially for large datasets.
# - Indexing reduces query execution time, making complex analytical queries more efficient.
# - Monitoring index usage can help refine the database structure for further optimization.

# %% [markdown]
# **Problem Statement 19 -**  Bulk write operations (multiple operations in one request)
#
#
# **Query** - db.movies.bulkWrite([
#   { insertOne: {
#     document: {
#       title: "The Matrix Resurrection",
#       year: 2021,
#       director: "Lana Wachowski",
#       genres: ["Action", "Sci-Fi"]
#     }
#   }},
#   { updateOne: {
#     filter: { title: "Inception" },
#     update: { $set: { "imdb.rating": 8.8 } }
#   }},
#   { deleteOne: {
#     filter: { title: "The Room" }
#   }}
# ]);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - **1 document inserted** → A new movie titled *"The Matrix Resurrection"* was added with ID **'67d6c04926d2bd79458e4db0'**.
# - **1 document matched** → A document titled *"Inception"* was found.
# - **0 documents modified** → The rating of *"Inception"* was not updated.
# - **0 documents deleted** → No document titled *"The Room"* was deleted.
#
# **2. Meaning:**
# - The query performed three operations in one request:
#    - Inserted a new movie.
#    - Attempted to update *"Inception"*, but the rating was already 8.8, so no update occurred.
#    - Attempted to delete *"The Room"*, but no such document was found.
#
# **3. Insights:**
# - Bulk operations can handle multiple changes at once, improving efficiency.
# - Ensuring consistent data and indexing can increase the success of update and delete operations.
# - Bulk operations reduce network calls, enhancing overall performance.

# %% [markdown]
# **Problem Statement 20 -**  Rename the field imdb.rating to rating.
#
#
# **Query** - db.movies.updateMany(
#   {},
#   { $rename: { "imdb.rating": "rating" } }
# );

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - **2 documents matched** → Two documents with `imdb.rating` were found.
# - **1 document modified** → Only one document had the `imdb.rating` field renamed.
#
# **2. Meaning:**
# - The query attempted to rename `imdb.rating` to `rating` for all documents in the collection.
# - Only one document was modified because others might not have had the `imdb.rating` field.
#
# **3. Insights:**
# - Renaming fields helps standardize data structure and improve query consistency.
# - Ensuring that the field exists across all documents can increase the success rate.
# - Post-renaming queries involving rating will be faster and more efficient.

# %% [markdown]
# **Problem Statement 21 -** Update the movie "The Godfather" with a new rating; if it doesn't exist, create a new document.
#
#
#
# **Query** - db.movies.updateOne(
#   { title: "The Godfather" },
#   {
#     $set: {
#       year: 1972,
#       director: "Francis Ford Coppola",
#       genres: ["Crime", "Drama"],
#       "imdb.rating": 9.2
#     }
#   },
#   { upsert: true }
# );

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Results:**
# - **0 documents matched** → No existing document titled *"The Godfather"* was found.
# - **0 documents modified** → No existing document was updated.
# - **1 document upserted** → A new document for *"The Godfather"* was created with ID **'67d6c1784fec2d8f646e7f93'**.
#
# **2. Meaning:**
# - Since the movie *"The Godfather"* didn’t exist, the query created a new document using the `upsert` option.
# - The new document includes title, year, director, genres, and IMDb rating.
#
# **3. Insights:**
# - `upsert` ensures that important records are created if they don’t exist, preventing data gaps.
# - This is useful for data consistency when updating or adding frequently used documents.
# - Regular use of `upsert` can simplify data maintenance and reduce manual corrections.

# %% [markdown]
# # **MongoDB Dashboard**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Dashboard Analysis (Chart-by-Chart)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Number of Movies**
#
# Value: 23,539
#
# This shows the total number of movies in the dataset. It's a high-level metric providing a sense of the dataset's size and coverage.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Total Number of Language Entries in Movies**
#
# Value: 33,172
#
# This represents the total number of language entries across all movies. Since a single movie can have multiple languages, this number is higher than the total number of movies.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Distribution of Movies by Genre**
#
# Displays a donut chart showing the share of each genre in the dataset.
# Drama, Comedy, and Romance seem to have a larger share compared to others, indicating that these are the most common genres in the dataset.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Top 10 Movie Genres by Count**
#
# Shows the top 10 genres based on the number of movies produced.
# Drama is the most produced genre, followed by Comedy and Romance, reinforcing the insight from the pie chart.
# The significant drop after the top few genres suggests that the movie industry is highly concentrated around certain genres.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Languages Used Most Frequently in Movies**
#
# English is the dominant language with over 16,000 entries, indicating that the dataset is heavily skewed toward English-language films.
# French, Spanish, and German follow, but their counts are significantly lower than English.
# The distribution suggests a strong Western influence in the dataset.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Top Genres by Award-Winning Movies**
#
# Drama is not only the most produced genre but also has the highest number of award-winning movies (~13,736).
# Romance and Documentary also have notable award-winning counts.
# The chart shows that genres like Sport, Film-Noir, and Talk-Show have fewer award-winning movies, possibly due to lower production volumes or different audience reception.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Top Directors by Movie Ratings**
#
# This word cloud highlights directors based on the average ratings of their movies.
#
# - **Woody Allen**, **Werner Herzog**, and **John Ford** stand out with the largest text size, indicating consistently high-rated films.
# - Directors like **Martin Scorsese**, **John Huston**, and **Sidney Lumet** also have substantial presence, suggesting a strong record of critically acclaimed movies.
# - Smaller names such as **Ken Loach** and **Billy Wilder** indicate directors with fewer top-rated films or less frequent standout performances.
#
# This visualization effectively highlights directors known for producing high-quality films, with larger text size emphasizing their strong average ratings.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Trend of Movie Nominations by Year and Runtime**
#
# Shows how the number of nominations changes over time and by runtime.
# Recent decades (2000s–2020s) have a higher concentration of nominated movies with longer runtimes.
# Suggests that longer movies might have a higher chance of receiving nominations.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Mean IMDb Rating by Country**
#
# Darker blue shades represent higher average ratings.
# The USA and parts of Europe show higher average IMDb ratings.
# Lighter shades in some regions suggest that either fewer movies are produced or they receive lower average ratings.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Movie Rating Trends by Genre Over Time**
#
# This candlestick chart shows how movie ratings have varied by decade.
#
# - **Green bars** = Increased ratings (closing > opening)
# - **Red bars** = Decreased ratings (closing < opening)
# - **Longer wicks** = Greater variation in ratings
# - Ratings were more stable in the **1940s–1970s** and more volatile in the **1980s–1990s**.
# - Recent decades show consistent ratings with a slight upward trend.
